# %%
import stochastic as st

sample = st.RandomWalk(10, 1000)
sample.plot()

# %%
import numpy as np

sample = st.RandomWalk(10, 1000)
print(sample.abs_var)
print(sample.quad_var)
sample.plot()
# Out:
# 100.0
# 10.0
